# %%
# =============================================================
# Tumor Habitat Segmentation — V2
# Run this cell to launch the graphical interface.
# All pipeline logic is in the tumor_habitat/ package.
# Edit config.py to change default constants.
# =============================================================
# %load_ext autoreload
# %autoreload 2

import sys, os
import matplotlib
from pathlib import Path
matplotlib.use('Agg')  # Must be set before any other matplotlib import

PACKAGE_DIR = str(Path().resolve())
if PACKAGE_DIR not in sys.path:
    sys.path.insert(0, PACKAGE_DIR)

from app import launch
launch()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\laboratorio\miniconda3\envs\seg_hab_env\lib\tkinter\__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "C:\Users\laboratorio\tumor_habitat_V4\app.py", line 1481, in _run
#     self.btn_run.config(state='disabled', text=t("running"))
# UnboundLocalError: local variable 't' referenced before assignment
