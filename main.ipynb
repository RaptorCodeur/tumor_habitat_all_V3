# %%
# =============================================================
# Tumor Habitat Segmentation — V2
# Run this cell to launch the graphical interface.
# All pipeline logic is in the tumor_habitat/ package.
# Edit config.py to change default constants.
# =============================================================
# %load_ext autoreload
# %autoreload 2

import sys, os
import matplotlib
from pathlib import Path
matplotlib.use('Agg')  # Must be set before any other matplotlib import

PACKAGE_DIR = str(Path().resolve())
if PACKAGE_DIR not in sys.path:
    sys.path.insert(0, PACKAGE_DIR)

from app import launch
launch()
# Out:
# C:\Users\laboratorio\tumor_habitat_all_V3\pipeline\habitat_atlas.py:101: RuntimeWarning: divide by zero encountered in log
#   entropy = -np.sum(post * np.log(post + 1e-300)) # classification entropy
# C:\Users\laboratorio\tumor_habitat_all_V3\pipeline\habitat_atlas.py:101: RuntimeWarning: invalid value encountered in multiply
#   entropy = -np.sum(post * np.log(post + 1e-300)) # classification entropy
# C:\Users\laboratorio\tumor_habitat_all_V3\pipeline\habitat_atlas.py:101: RuntimeWarning: divide by zero encountered in log
#   entropy = -np.sum(post * np.log(post + 1e-300)) # classification entropy
# C:\Users\laboratorio\tumor_habitat_all_V3\pipeline\habitat_atlas.py:101: RuntimeWarning: invalid value encountered in multiply
#   entropy = -np.sum(post * np.log(post + 1e-300)) # classification entropy
# C:\Users\laboratorio\tumor_habitat_all_V3\pipeline\habitat_atlas.py:101: RuntimeWarning: divide by zero encountered in log
#   entropy = -np.sum(post * np.log(post + 1e-300)) # classification entropy
# C:\Users\laboratorio\tumor_habitat_all_V3\pipeline\habitat_atlas.py:101: RuntimeWarning: invalid value encountered in multiply
#   entropy = -np.sum(post * np.log(post + 1e-300)) # classification entropy
# C:\Users\laboratorio\tumor_habitat_all_V3\pipeline\habitat_atlas.py:101: RuntimeWarning: divide by zero encountered in log
#   entropy = -np.sum(post * np.log(post + 1e-300)) # classification entropy
# C:\Users\laboratorio\tumor_habitat_all_V3\pipeline\habitat_atlas.py:101: RuntimeWarning: invalid value encountered in multiply
#   entropy = -np.sum(post * np.log(post + 1e-300)) # classification entropy
# C:\Users\laboratorio\tumor_habitat_all_V3\pipeline\habitat_atlas.py:101: RuntimeWarning: divide by zero encountered in log
#   entropy = -np.sum(post * np.log(post + 1e-300)) # classification entropy
# C:\Users\laboratorio\tumor_habitat_all_V3\pipeline\habitat_atlas.py:101: RuntimeWarning: invalid value encountered in multiply
#   entropy = -np.sum(post * np.log(post + 1e-300)) # classification entropy
# C:\Users\laboratorio\tumor_habitat_all_V3\pipeline\habitat_atlas.py:101: RuntimeWarning: divide by zero encountered in log
#   entropy = -np.sum(post * np.log(post + 1e-300)) # classification entropy
# C:\Users\laboratorio\tumor_habitat_all_V3\pipeline\habitat_atlas.py:101: RuntimeWarning: invalid value encountered in multiply
#   entropy = -np.sum(post * np.log(post + 1e-300)) # classification entropy
# C:\Users\laboratorio\tumor_habitat_all_V3\pipeline\habitat_atlas.py:101: RuntimeWarning: divide by zero encountered in log
#   entropy = -np.sum(post * np.log(post + 1e-300)) # classification entropy
# C:\Users\laboratorio\tumor_habitat_all_V3\pipeline\habitat_atlas.py:101: RuntimeWarning: invalid value encountered in multiply
#   entropy = -np.sum(post * np.log(post + 1e-300)) # classification entropy
# C:\Users\laboratorio\tumor_habitat_all_V3\pipeline\habitat_atlas.py:101: RuntimeWarning: divide by zero encountered in log
#   entropy = -np.sum(post * np.log(post + 1e-300)) # classification entropy
# C:\Users\laboratorio\tumor_habitat_all_V3\pipeline\habitat_atlas.py:101: RuntimeWarning: invalid value encountered in multiply
#   entropy = -np.sum(post * np.log(post + 1e-300)) # classification entropy
# C:\Users\laboratorio\tumor_habitat_all_V3\pipeline\habitat_atlas.py:101: RuntimeWarning: divide by zero encountered in log
#   entropy = -np.sum(post * np.log(post + 1e-300)) # classification entropy
# C:\Users\laboratorio\tumor_habitat_all_V3\pipeline\habitat_atlas.py:101: RuntimeWarning: invalid value encountered in multiply
#   entropy = -np.sum(post * np.log(post + 1e-300)) # classification entropy
# C:\Users\laboratorio\tumor_habitat_all_V3\pipeline\habitat_atlas.py:101: RuntimeWarning: divide by zero encountered in log
#   entropy = -np.sum(post * np.log(post + 1e-300)) # classification entropy
# C:\Users\laboratorio\tumor_habitat_all_V3\pipeline\habitat_atlas.py:101: RuntimeWarning: invalid value encountered in multiply
#   entropy = -np.sum(post * np.log(post + 1e-300)) # classification entropy
